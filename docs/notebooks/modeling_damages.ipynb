# %% [markdown]
# # Modeling damages
#
# This notebook proposes a draft version of what GIS-driven damage function can look like.

# %%
import xarray as xr
import pandas as pd

# %%
ds = xr.open_dataset('../data/processed/dataset.nc')
ds
# Out:
# <xarray.Dataset> Size: 109MB
# Dimensions:        (y: 2160, x: 1800, band: 1)
# Coordinates:
#   * y              (y) float64 17kB 14.95 14.95 14.95 ... 14.35 14.35 14.35
#   * x              (x) float64 14kB -61.25 -61.25 -61.25 ... -60.75 -60.75
#   * band           (band) int32 4B 1
# Data variables:
#     elevation      (y, x) float32 16MB ...
#     buildings      (y, x) int32 16MB ...
#     road_distance  (y, x) float32 16MB ...
#     exposure       (y, x) float64 31MB ...
#     landcover      (band, y, x) float64 31MB ...
#     spatial_ref    int32 4B ...

# %% [markdown]
# ## Building destruction
#
# Let's start with a simple building destruction model. We'll assume that the
