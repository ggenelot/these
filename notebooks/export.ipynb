# %% [markdown]
# # Data export notebook
#
# Notebook that can be used to easily export data to other standard format than xarray : as a QGIS project, as a .shp, etc. so that the model can be used by anyone
