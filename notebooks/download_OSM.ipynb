# %%
# import osmnx
import osmnx as ox
import geopandas as gpd
import matplotlib.pyplot as plt
import earth_osm as eo

place_name="martinique"


# List key-value pairs for tags
tags = {'building': True}

# %%
#b uildings = ox.features_from_place(place_name, tags)
# Out:
#   Cell In[2], line 1
#     b uildings = ox.features_from_place(place_name, tags)
#       ^
# SyntaxError: invalid syntax

# %%
#buildings.plot()
# Out:
# <Axes: >

# %%
buildings  = buildings.loc[:,buildings.columns.str.contains('addr:|geometry')]
buildings = buildings.loc[buildings.geometry.type=='Polygon']

# %%
buildings.to_file('../data/OSM/buildings.shp')
# Out:
# C:\Users\ggenelot\AppData\Local\Temp\ipykernel_36748\3601013712.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   buildings.to_file('../data/OSM/buildings.shp')
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'addr:city' to 'addr_city'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'addr:postcode' to 'addr_postc'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'addr:street' to 'addr_stree'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'addr:housenumber' to 'addr_house'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'source:geometry' to 'source_geo'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'addr:place' to 'addr_place'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'addr:country' to 'addr_count'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'addr:housename' to 'addr_hou_1'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'addr:full' to 'addr_full'
#   ogr_write(

# %%
highway = ox.features_from_place(place_name, {'highway':True})

# %%
# Shapefile layers must contain a single geometry type.
# Split the mixed-geometry GeoDataFrame into separate files by geometry type.
pts = highway.loc[highway.geometry.type.str.contains('Point', na=False)]
lines = highway.loc[highway.geometry.type.str.contains('Line', na=False)]
polys = highway.loc[highway.geometry.type.str.contains('Polygon', na=False)]

out_dir = '../data/raw/OSM'
if len(pts):
	#pts.to_file(f'{out_dir}/highway_points.shp')
	pass
if len(lines):
	lines.to_file(f'{out_dir}/highway_lines.shp')
if len(polys):
	#polys.to_file(f'{out_dir}/highway_polygons.shp')
	pass
# Out:
# C:\Users\ggenelot\AppData\Local\Temp\ipykernel_28448\1160728836.py:12: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   lines.to_file(f'{out_dir}/highway_lines.shp')
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'crossing_ref' to 'crossing_r'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'crossing:island' to 'crossing_i'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'tactile_paving' to 'tactile_pa'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'traffic_calming' to 'traffic_ca'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'crossing:signals' to 'crossing_s'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'public_transport' to 'public_tra'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'survey:date' to 'survey_dat'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'description' to 'descriptio'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'internet_access' to 'internet_a'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'name:en' to 'name_en'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'name:fr' to 'name_fr'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'crossing:markings' to 'crossing_m'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'holding_position:type' to 'holding_po'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'enforcement' to 'enforcemen'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'departures_board' to 'departures'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'description:de' to 'descript_1'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'traffic_signals' to 'traffic_si'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'check_date:shelter' to 'check_date'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'check_date' to 'check_da_1'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'check_date:bin' to 'check_da_2'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'check_date:lit' to 'check_da_3'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'check_date:tactile_paving' to 'check_da_4'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'traffic_signals:direction' to 'traffic__1'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'name:ru' to 'name_ru'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'cycleway:right' to 'cycleway_r'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'maxspeed:type' to 'maxspeed_t'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'destination' to 'destinatio'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'destination:ref' to 'destinat_1'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'cycleway:both' to 'cycleway_b'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'destination:symbol' to 'destinat_2'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'name:etymology:wikidata' to 'name_etymo'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'lane_markings' to 'lane_marki'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'admin_level' to 'admin_leve'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'source:maxspeed' to 'source_max'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'source:geometry' to 'source_geo'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'source:ref' to 'source_ref'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'ref:FR:FANTOIR' to 'ref_FR_FAN'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'FIXME' to 'FIXME_1'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'source:name' to 'source_nam'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'turn:lanes' to 'turn_lanes'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'cycleway:left' to 'cycleway_l'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'motor_vehicle' to 'motor_vehi'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'trail_visibility' to 'trail_visi'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'sidewalk:both' to 'sidewalk_b'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'source:old_name' to 'source_old'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'addr:city' to 'addr_city'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'addr:street' to 'addr_stree'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'check_date:surface' to 'check_da_5'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'addr:postcode' to 'addr_postc'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'check_date:handrail' to 'check_da_6'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'handrail:right' to 'handrail_r'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'handrail:left' to 'handrail_l'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'orientation' to 'orientatio'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'parking:both' to 'parking_bo'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'parking:left' to 'parking_le'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'maxspeed:backward' to 'maxspeed_b'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'parking:lane:left' to 'parking_la'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'parking:lane:right' to 'parking__1'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'parking:lane:both' to 'parking__2'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'lanes:backward' to 'lanes_back'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'lanes:forward' to 'lanes_forw'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'sidewalk:left' to 'sidewalk_l'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'ramp:wheelchair' to 'ramp_wheel'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'maxweight:signed' to 'maxweight_'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'name:gcf' to 'name_gcf'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'oneway:bus' to 'oneway_bus'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'oneway:hgv' to 'oneway_hgv'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'conditional' to 'conditiona'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'oneway:conditional' to 'oneway_con'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'parking:right' to 'parking_ri'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'name:ar' to 'name_ar'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'parking:left:orientation' to 'parking__3'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'sidewalk:right' to 'sidewalk_r'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'cycleway:right:oneway' to 'cycleway_1'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'wheelchair:description:fr' to 'wheelcha_1'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'ramp:luggage' to 'ramp_lugga'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'maxspeed:forward' to 'maxspeed_f'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'source:alt_name' to 'source_alt'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'source:imagery' to 'source_ima'
#   ogr_write(
# c:\Users\ggenelot\AppData\Local\miniconda3\envs\modele-SIG\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'cycleway:both:lane' to 'cycleway_2'
#   ogr_write(
# INFO:pyogrio._io:Created 42,629 records

# %%
power = ox.features_from_place(place_name, {'power':True})

# %%
eo.get_osm_data(
    primary_name='power',
    region_list=place_name,
    feature_list=['substation', 'line'],
    update=False,
    mp=True,
    data_dir='./data/raw/OSM/earth_data',
    out_format=['csv', 'geojson'],
    out_aggregate=False,
    data_source='geofabrik'  # or 'overpass'
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 eo.get_osm_data(
#       2     primary_name='power',
#       3     region_list=place_name,
#       4     feature_list=['substation', 'line'],
#       5     update=False,
#       6     mp=True,
#       7     data_dir='./data/raw/OSM/earth_data',
#       8     out_format=['csv', 'geojson'],
#       9     out_aggregate=False,
#      10     data_source='geofabrik'  # or 'overpass'
#      11 )
#
# AttributeError: module 'earth_osm' has no attribute 'get_osm_data'

# %%
import earth_osm as eo

eo.save_osm_data(
    primary_name='power',
    region_list=['benin', 'monaco'],
    feature_list=['substation', 'line'],
    update=False,
    mp=True,
    data_dir='./earth_data',
    out_format=['csv', 'geojson'],
    out_aggregate=False,
    data_source='geofabrik'  # or 'overpass'
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 import earth_osm as eo
# ----> 3 eo.save_osm_data(
#       4     primary_name='power',
#       5     region_list=['benin', 'monaco'],
#       6     feature_list=['substation', 'line'],
#       7     update=False,
#       8     mp=True,
#       9     data_dir='./earth_data',
#      10     out_format=['csv', 'geojson'],
#      11     out_aggregate=False,
#      12     data_source='geofabrik'  # or 'overpass'
#      13 )
#
# AttributeError: module 'earth_osm' has no attribute 'save_osm_data'

# %%
import earth_osm
print(dir(earth_osm))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'f', 'fp_version', 'logger', 'logging', 'os']
